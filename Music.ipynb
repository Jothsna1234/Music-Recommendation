# %%
import pandas as pd
df_1 = pd.read_csv('/content/drive/MyDrive/SpotifyFeatures.csv')
print(df_1)
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
df_1["popularity"].mean()
# Out:
# 41.12750241701579

# %%
df_1.sort_values(by=['artist_name'], ascending=[False])
# Out:
#              genre     artist_name  \
# 84072          R&B             정진우
# 218661       World  어노인팅 Anointing
# 218602       World  어노인팅 Anointing
# 221745       World  어노인팅 Anointing
# 220986       World  어노인팅 Anointing
# ...            ...             ...
# 38439   Electronic             !!!
# 38418   Electronic             !!!
# 38351   Electronic             !!!
# 24641   Electronic             !!!
# 37300   Electronic             !!!
#
#                                                track_name  \
# 84072                          I'll Find You (feat. June)
# 218661                        나는 예배자 입니다 I Am a Worshiper
# 218602                                        You Are God
# 221745                                       소원 One Thing
# 220986        하나님의 그늘 아래 Under the Shadow of the Almighty
# ...                                                   ...
# 38439                         Throw Yourself In The River
# 38418                                       Sick Ass Moon
# ...

# %%
df_1.agg("popularity")
# Out:
# 0          0
# 1          1
# 2          3
# 3          0
# 4          4
#           ..
# 232720    39
# 232721    38
# 232722    47
# 232723    44
# 232724    35
# Name: popularity, Length: 232725, dtype: int64

# %%
n = 2
 
# Removing last n rows
df_1_dropped_last_n = df_1.iloc[:-n]
 
# Printing dataframe
print(df_1_dropped_last_n)
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# ...       ...                       ...
# 232718   Soul              Muddy Waters
# 232719   Soul        Bobby "Blue" Bland
# 232720   Soul                     Slave
# 232721   Soul  Jr Thomas & The Volcanos
# 232722   Soul              Muddy Waters
#
#                                                track_name  \
# 0                             C'est beau de faire un Show
# 1                        Perdu d'avance (par Gad Elmaleh)
# 2                          Don't Let Me Be Lonely Tonight
# 3                          Dis-moi Monsieur Gordon Cooper
# 4                                               Ouverture
# ...                                                   ...
# 232718  I Just Want To Make Love To You - Electric Mud...
# ...
